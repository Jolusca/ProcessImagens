# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pydicom

# %%
arara = cv2.imread('arara_ESPERADA.png',0)
arara = cv2.cvtColor(arara,cv2.COLO)

# %%
arara = cv2.imread('arara_ORIGINAL.png')
